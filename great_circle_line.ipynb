# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# for autocompletion on pandas dataframes disable the autocompletion tool 'jedi'
# %config Completer.use_jedi = False

# formatter
#%load_ext nb_black

# %%
fig = plt.figure(figsize=(20,10))
# Setup Base Map
m = plt.axes(projection=ccrs.Robinson())
m.set_global()
m.add_feature(cfeature.COASTLINE) #edgecolor="tomato")
m.add_feature(cfeature.LAND)
m.add_feature(cfeature.BORDERS, linestyle=':')

# plt.plot([port1_lon, port2_lon], [port1_lat, port1_lat], color='red',  transform=ccrs.Geodetic())

#plt.plot([-0.08, 132], [51.5, 43.17], color='blue',  transform=ccrs.Geodetic())
#plt.plot([-0.08, -52.26], [51.5, 4.85], color='blue',  transform=ccrs.Geodetic())

#m.scatter(long_degree, lat_degree)
m.scatter([-0.08,7,-52.27],[51.5,58,4.85],transform=ccrs.PlateCarree(),
            color='red',
            marker='o',
         )#, latlon=True)

#plt.plot([-0.08, 7.03],[51.5, 58], color='blue',transform=ccrs.Geodetic() )
plt.plot([-0.08, -52.27 ], [51.5, 4.85], color='blue',transform=ccrs.Geodetic())
#plt.plot([-0.08, 132], [51.5, 43.17], color='blue',  transform=ccrs.Geodetic())




#[0,7],[51,58]
